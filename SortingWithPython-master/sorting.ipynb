# %% [markdown]
# <a href="https://colab.research.google.com/github/arivle/SortingWithPython/blob/master/sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = [2,1,0,2,1,3,0,2,4,0,3,2,3,4,2,2,2,4,3,0]
frek = pd.Series(data).value_counts().reset_index().sort_values('index').reset_index(drop='True')
frek.columns = ['nilai rentang', 'frekuensi']
print(frek)

#=======histogram===========
plt.hist(data, bins=30)
plt.ylabel('frekuensi')
plt.show()
# Out:
#    nilai rentang  frekuensi
# 0              0          4
# 1              1          2
# 2              2          7
# 3              3          4
# 4              4          3

# %%
taskdata = [84,86,89,92,82,86,89,92,80,86,87,90]
jumlah  = pd.Series(taskdata).sum()
print(jumlah)
# Out:
# 1043

# %%
#scatter diagram
#create data
N=200
g1 = (0.6 + 0.6 * np.random.rand(N), np.random.rand(N))
g2 = (0.4 + 0.3 * np.random.rand(N), 0.5 * np.random.rand(N))
g3 = (0.3 * np.random.rand(N), 0.3 * np.random.rand(N))
x,y = g1
print (x,y)

data = (g1, g2, g3)
colors = ("red", "green", "blue")
groups = ("coffee", "tea", "water")

#create plot
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

for data, color, group in zip (data, colors, groups):
  x,y = data
  ax.scatter(x,y,alpha=0.8, c=color, edgecolors='none', s=30, label=group)
  
plt.title('matplot scatter data')
plt.legend(loc=2)
plt.show()
# Out:
# [1.16918637 0.62137272 0.81666336 1.10065256 0.70963089 0.97908402
#  0.91338169 0.98971052 0.61033009 0.93537199 0.85665284 0.64562085
#  0.64092507 1.18417554 1.08835044 0.9934187  0.79240648 0.90125848
#  0.71037701 1.12312792 1.04536282 0.88229142 0.93327878 0.72041142
#  0.67506661 1.04657492 0.75899276 0.68952651 0.90441127 1.00752434
#  0.99913398 0.66475497 1.18762441 0.98273525 0.7791546  1.13128901
#  0.83989205 0.60476229 0.729786   0.67932576 1.08155603 0.95020453
#  1.03112574 0.79100945 0.64662384 1.10450976 1.01534535 0.90674783
#  1.02836338 0.64197562 1.17729474 0.69894695 0.69783951 0.73662698
#  0.83708651 1.1397083  1.09915892 0.81877926 1.00745061 1.07663231
#  1.15429256 0.77191524 0.83402825 1.06612325 1.00093159 0.85603851
#  0.66938287 0.88591238 0.84383162 0.63330706 0.96807671 0.77090293
#  0.76502244 1.11853783 1.19105351 1.13101485 1.02429272 0.91535826
#  1.10430066 0.95932109 0.89392452 0.84269809 0.66818618 1.03346676
# ...

# %%
#using another data
df_cars = pd.read_csv("https://gist.githubusercontent.com/seankross/a412dfbd88b3db70b74b/raw/5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1/mtcars.csv")
print(df_cars)
df_cars.mean()
# Out:
#                   model   mpg  cyl   disp   hp  ...   qsec  vs  am  gear  carb
# 0             Mazda RX4  21.0    6  160.0  110  ...  16.46   0   1     4     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110  ...  17.02   0   1     4     4
# 2            Datsun 710  22.8    4  108.0   93  ...  18.61   1   1     4     1
# 3        Hornet 4 Drive  21.4    6  258.0  110  ...  19.44   1   0     3     1
# 4     Hornet Sportabout  18.7    8  360.0  175  ...  17.02   0   0     3     2
# 5               Valiant  18.1    6  225.0  105  ...  20.22   1   0     3     1
# 6            Duster 360  14.3    8  360.0  245  ...  15.84   0   0     3     4
# 7             Merc 240D  24.4    4  146.7   62  ...  20.00   1   0     4     2
# 8              Merc 230  22.8    4  140.8   95  ...  22.90   1   0     4     2
# 9              Merc 280  19.2    6  167.6  123  ...  18.30   1   0     4     4
# 10            Merc 280C  17.8    6  167.6  123  ...  18.90   1   0     4     4
# ...
