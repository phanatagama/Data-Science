# %%
# Persiapan membuat data
import pandas as pd
import random

pelajaran = ['Matematika', 'Fisika', 'Biologi', 'Kimia', 'Geologi', 'Ekonomi']
kelas = ['12A', '12B', '12C', '12D']

hasil_nilai = {
    'siswa_id' : range(1, 21),
    'pelajaran' : [random.choice(pelajaran) for i in range(20)],
    'nilai' : [random.choice(range(0, 100)) for i in range(20)],
    'jenis-kelamin' : [random.choice(['laki-laki', 'perempuan']) for i in range(20)],
    'kelas' : [random.choice(kelas) for i in range(20)]
}

df = pd.DataFrame(hasil_nilai)
df
# Out:
#     siswa_id   pelajaran  nilai jenis-kelamin kelas
# 0          1      Fisika     63     perempuan   12A
# 1          2  Matematika     17     perempuan   12C
# 2          3     Geologi     94     laki-laki   12B
# 3          4     Biologi     30     laki-laki   12D
# 4          5     Geologi     30     laki-laki   12A
# 5          6     Biologi     32     perempuan   12C
# 6          7     Ekonomi     48     perempuan   12D
# 7          8     Biologi     76     perempuan   12A
# 8          9     Geologi     14     perempuan   12B
# 9         10     Ekonomi     48     laki-laki   12C
# 10        11      Fisika     90     laki-laki   12D
# 11        12     Geologi     12     laki-laki   12A
# 12        13     Ekonomi     75     perempuan   12B
# 13        14       Kimia     35     perempuan   12C
# 14        15     Ekonomi      0     laki-laki   12A
# 15        16      Fisika     89     laki-laki   12A
# 16        17     Geologi     79     perempuan   12B
# 17        18      Fisika     45     laki-laki   12C
# 18        19       Kimia     33     laki-laki   12A
# 19        20       Kimia     73     perempuan   12A

# %% [markdown]
# <h2>Quiz 1 : Indexing</h2>
#
# 1. Lakukan indexing terhadap dataframe untuk mengakses column nilai dan kelas saja
# 2. Lakukan indexing terhadap dataframe untuk mengakses row 5 sampai 10 beserta column pelajaran dan nilai

# %%
# code here
df[['nilai','kelas']]
# Out:
#     nilai kelas
# 0      63   12A
# 1      17   12C
# 2      94   12B
# 3      30   12D
# 4      30   12A
# 5      32   12C
# 6      48   12D
# 7      76   12A
# 8      14   12B
# 9      48   12C
# 10     90   12D
# 11     12   12A
# 12     75   12B
# 13     35   12C
# 14      0   12A
# 15     89   12A
# 16     79   12B
# 17     45   12C
# 18     33   12A
# 19     73   12A

# %%
df.iloc[5:11,1:3]
# Out:
#    pelajaran  nilai
# 5    Biologi     32
# 6    Ekonomi     48
# 7    Biologi     76
# 8    Geologi     14
# 9    Ekonomi     48
# 10    Fisika     90

# %% [markdown]
# <h2>Quiz 2 : Filter DataFrame Dengan Boolean</h2>
#
# 1. Tampilkan semua data siswa pada mata pelajaran Ekonomi dan Fisika
# 2. Tampilkan semua data siswa yang mempunyai nilai lebih dari 50 di mata pelajaran Kimia
# 3. Tampilkan semua data yang mempunyai nilai lebih dari 70, berjnis kelamin perempuan dan di kelas 12C

# %%
# code here
df[(df.pelajaran == 'Ekonomi') | (df.pelajaran == 'Fisika')]
# Out:
#     siswa_id pelajaran  nilai jenis-kelamin kelas
# 0          1    Fisika     63     perempuan   12A
# 6          7   Ekonomi     48     perempuan   12D
# 9         10   Ekonomi     48     laki-laki   12C
# 10        11    Fisika     90     laki-laki   12D
# 12        13   Ekonomi     75     perempuan   12B
# 14        15   Ekonomi      0     laki-laki   12A
# 15        16    Fisika     89     laki-laki   12A
# 17        18    Fisika     45     laki-laki   12C

# %%
pelajaran = df.pelajaran == 'Kimia'
nilai = df.nilai > 50
df[(nilai) & (pelajaran)]
# Out:
#     siswa_id pelajaran  nilai jenis-kelamin kelas
# 19        20     Kimia     73     perempuan   12A

# %%
nilai = df.nilai > 70
kelas = df.kelas == '12C'
jK = df['jenis-kelamin'] == 'perempuan'
df[(nilai) & (jK) & (kelas)]
# Out:
# Empty DataFrame
# Columns: [siswa_id, pelajaran, nilai, jenis-kelamin, kelas]
# Index: []

# %% [markdown]
# <h2>Quiz 3 : Data Transformation</h2>
#
# lakukan data transformasi terhadap column 'nilai' dengan fungsi transformasi, berikut rumus dari normalisasi
#
# ![image.png](attachment:image.png)

# %%
# code here
def transformasiData(nilai):
    return ((nilai-nilai.min())/(nilai.max()-nilai.min()))
df[['nilai']].apply(transformasiData)
# Out:
#        nilai
# 0   0.670213
# 1   0.180851
# 2   1.000000
# 3   0.319149
# 4   0.319149
# 5   0.340426
# 6   0.510638
# 7   0.808511
# 8   0.148936
# 9   0.510638
# 10  0.957447
# 11  0.127660
# 12  0.797872
# 13  0.372340
# 14  0.000000
# 15  0.946809
# 16  0.840426
# 17  0.478723
# 18  0.351064
# 19  0.776596
